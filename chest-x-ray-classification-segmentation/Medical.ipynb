# %%
# !pwd
# Out:
# /content

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Aug 18 13:44 .
# drwxr-xr-x 1 root root 4096 Aug 19 21:27 ..
# drwxr-xr-x 4 root root 4096 Aug 18 13:44 .config
# drwxr-xr-x 1 root root 4096 Aug 18 13:44 sample_data

# %%
# !git clone https://github.com/Ebenezeragyemang10/machine-learning-projects.git
# Out:
# Cloning into 'machine-learning-projects'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 23 (delta 4), reused 16 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 3.26 MiB | 16.06 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd /content/machine-learning-projects
# Out:
# /content/machine-learning-projects
